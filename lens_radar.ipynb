# %%
import numpy as np
import matplotlib.pyplot as plt

F = 7.5
D = 36
dc = 2.85
n = np.sqrt(dc)
T = (np.sqrt(4*(F**2)+(D**2))-2*F)/(2*(n-1))

print(n)
print(T)

x1=F

for y1 in range(int(D)+1):
    y1/=2
    x2 = (((n-1)*T - np.sqrt((F**2)+(y1**2)))*np.sqrt(((n**2)-1)*(y1**2) + (n**2)*(F**2)) + (n**2)*F*np.sqrt((F**2)+(y1**2)))/((n**2)*np.sqrt((F**2)+(y1**2))-np.sqrt(((n**2)-1)*(y1**2)+(n**2)*(F**2)))
    y2 = y1*(1+(x2-F)/(np.sqrt(((n**2)-1)*(y1**2)+(n**2)*(F**2))))
    plt.scatter(x2, y2)
    plt.scatter(x1, y1)

for y1 in range(int(D)+1):
    y1 = -y1/2
    x2 = (((n-1)*T - np.sqrt((F**2)+(y1**2)))*np.sqrt(((n**2)-1)*(y1**2) + (n**2)*(F**2)) + (n**2)*F*np.sqrt((F**2)+(y1**2)))/((n**2)*np.sqrt((F**2)+(y1**2))-np.sqrt(((n**2)-1)*(y1**2)+(n**2)*(F**2)))
    y2 = y1*(1+(x2-F)/(np.sqrt(((n**2)-1)*(y1**2)+(n**2)*(F**2))))
    plt.scatter(x2, y2)
    plt.scatter(x1, y1)

plt.show()

print("(((",n,"-1)*",T," - sqrt((",F**2,")+(t*t)))*sqrt(((",n**2,")-1)*(t*t) + (",n**2,")*(",F**2,")) + (",n**2,")*",F,"*sqrt((",F**2,")+(t*t)))/((",n**2,")*sqrt((",F**2,")+(t*t))-sqrt(((",n**2,")-1)*(t*t)+(",n**2,")*(",F**2,")))")
print("t*(1+(x(t)-",F,")/(sqrt(((",n**2,")-1)*(t*t)+(",n**2,")*(",F**2,"))))")
# Out:
# 1.6881943016134133
# 17.43693601046538
# ((( 1.6881943016134133 -1)* 17.43693601046538  - sqrt(( 56.25 )+(t*t)))*sqrt((( 2.8500000000000005 )-1)*(t*t) + ( 2.8500000000000005 )*( 56.25 )) + ( 2.8500000000000005 )* 7.5 *sqrt(( 56.25 )+(t*t)))/(( 2.8500000000000005 )*sqrt(( 56.25 )+(t*t))-sqrt((( 2.8500000000000005 )-1)*(t*t)+( 2.8500000000000005 )*( 56.25 )))
# t*(1+(x(t)- 7.5 )/(sqrt((( 2.8500000000000005 )-1)*(t*t)+( 2.8500000000000005 )*( 56.25 ))))
